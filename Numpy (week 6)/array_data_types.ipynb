# %%
import numpy as np

# %%
#Data Types
arr = np.array([1, 2, 3.14, 4, 5])
print(arr.dtype)

complex_arr = np.array([5 + 6j])
print(complex_arr, complex_arr.dtype)

arr_object = np.array(['apple', {5}, 5])
print(arr_object, arr_object.dtype)
# Out:
# float64
# [5.+6.j] complex128
# ['apple' {5} 5] object
