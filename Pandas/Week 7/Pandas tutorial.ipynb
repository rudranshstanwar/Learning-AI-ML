# %%
import pandas as pd

# %%
info = {
    "Name" : ["Rahul", "Harshita", "Shradha"],
    "CGPA" : [9.5, 7.5, 8.5]
}
df = pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   7.5
# 2   Shradha   8.5

# %%
df
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   7.5
# 2   Shradha   8.5
